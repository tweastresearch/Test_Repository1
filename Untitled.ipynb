# %%
conda info --envs
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     /opt/anaconda3
# API_Ext              *   /opt/anaconda3/envs/API_Ext
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
a = 2
b = 5
sum = a + b

# %%
print (sum)
# Out:
# 7
